# %%
db = "./census/census.db"

# %%
# %load_ext sql
# %config SqlMagic.feedback=False
# %sql sqlite:///{db}?check_same_thread=false
# %sql SELECT name FROM sqlite_master WHERE type='table';
# Out:
#  * sqlite:///./census/census.db?check_same_thread=false
# [('census',)]

# %% [markdown]
# `$.schema`
# ```sql
# CREATE TABLE IF NOT EXISTS "census" (
#     "id" INTEGER,
#     "district" TEXT NOT NULL,
#     "locality" TEXT NOT NULL,
#     "families" INTEGER NOT NULL,
#     "households" INTEGER NOT NULL,
#     "population" INTEGER NOT NULL,
#     "male" INTEGER NOT NULL,
#     "female" INTEGER NOT NULL,
#     PRIMARY KEY("id")
# );
# ```

# %%
# %sql SELECT * FROM "census" LIMIT 20;
# Out:
#  * sqlite:///./census/census.db?check_same_thread=false
# [(1, 'Taplejung', 'Aathrai Tribeni Rural Municipality', 2869, 2735, 12288, 6005, 6283),
#  (2, 'Taplejung', 'Maiwakhola Rural Municipality', 2275, 2178, 10365, 5264, 5101),
#  (3, 'Taplejung', 'Meringden Rural Municipality', 2683, 2528, 12040, 6181, 5859),
#  (4, 'Taplejung', 'Mikwakhola Rural Municipality', 1862, 1792, 7991, 4000, 3991),
#  (5, 'Taplejung', 'Phaktanglung Rural Municipality', 2864, 2700, 11925, 6239, 5686),
#  (6, 'Taplejung', 'Phungling Municipality', 7306, 5888, 28786, 14160, 14626),
#  (7, 'Taplejung', 'Sidingba Rural Municipality', 2604, 2484, 10981, 5593, 5388),
#  (8, 'Taplejung', 'Sirijangha Rural Municipality', 3329, 3197, 14186, 7227, 6959),
#  (9, 'Taplejung', 'Pathivara Yangwarak Rural Municipality', 2738, 2637, 11797, 5855, 5942),
#  (10, 'Panchthar', 'Falelung Rural Municipality', 4940, 4773, 20531, 10211, 10320),
# ...

# %%
# %%sql
# CREATE VIEW "rural" AS
# SELECT * FROM "census"
# WHERE "locality" LIKE '%Rural%';
# Out:
#  * sqlite:///./census/census.db?check_same_thread=false
# []

# %%
# %sql SELECT * FROM "rural" LIMIT 20;
# Out:
#  * sqlite:///./census/census.db?check_same_thread=false
# [(1, 'Taplejung', 'Aathrai Tribeni Rural Municipality', 2869, 2735, 12288, 6005, 6283),
#  (2, 'Taplejung', 'Maiwakhola Rural Municipality', 2275, 2178, 10365, 5264, 5101),
#  (3, 'Taplejung', 'Meringden Rural Municipality', 2683, 2528, 12040, 6181, 5859),
#  (4, 'Taplejung', 'Mikwakhola Rural Municipality', 1862, 1792, 7991, 4000, 3991),
#  (5, 'Taplejung', 'Phaktanglung Rural Municipality', 2864, 2700, 11925, 6239, 5686),
#  (7, 'Taplejung', 'Sidingba Rural Municipality', 2604, 2484, 10981, 5593, 5388),
#  (8, 'Taplejung', 'Sirijangha Rural Municipality', 3329, 3197, 14186, 7227, 6959),
#  (9, 'Taplejung', 'Pathivara Yangwarak Rural Municipality', 2738, 2637, 11797, 5855, 5942),
#  (10, 'Panchthar', 'Falelung Rural Municipality', 4940, 4773, 20531, 10211, 10320),
#  (11, 'Panchthar', 'Falgunanda Rural Municipality', 5293, 4968, 21253, 10417, 10836),
# ...

# %%
# %%sql
# CREATE VIEW "total" AS
# SELECT
#     SUM("families") AS "families",
#     SUM("households") AS "households",
#     SUM("population") AS "population",
#     SUM("male") AS "male",
#     SUM("female") AS "female"
# FROM "census";
# Out:
#  * sqlite:///./census/census.db?check_same_thread=false
# []

# %%
# %sql SELECT * FROM "total";
# Out:
#  * sqlite:///./census/census.db?check_same_thread=false
# [(6759473, 5642674, 29074990, 14188639, 14886351)]

# %%
# %%sql
# CREATE VIEW "by_district" AS
# SELECT
#     "district",
#     SUM("families") AS "families",
#     SUM("households") AS "households",
#     SUM("population") AS "population",
#     SUM("male") AS "male",
#     SUM("female") AS "female"
# FROM "census"
# GROUP BY "district";
# Out:
#  * sqlite:///./census/census.db?check_same_thread=false
# []

# %%
# %sql SELECT * FROM "by_district" LIMIT 10;
# Out:
#  * sqlite:///./census/census.db?check_same_thread=false
# [('Achham', 49962, 39368, 228907, 105390, 123517),
#  ('Arghakhanchi', 49073, 45012, 176534, 80468, 96066),
#  ('Baglung', 65334, 58445, 248964, 115864, 133100),
#  ('Baitadi', 50472, 42288, 244400, 115426, 128974),
#  ('Bajhang', 38368, 32916, 189023, 88918, 100105),
#  ('Bajura', 28922, 23891, 138998, 67608, 71390),
#  ('Banke', 131920, 110130, 601666, 293679, 307987),
#  ('Bara', 134362, 112301, 742667, 379072, 363595),
#  ('Bardiya', 106429, 98917, 458922, 216081, 242841),
#  ('Bhaktapur', 108453, 70849, 425392, 213662, 211730)]

# %%
# %%sql
# CREATE VIEW "most_populated" AS
# SELECT
#     "district",
#     SUM("families") AS "families",
#     SUM("households") AS "households",
#     SUM("population") AS "population",
#     SUM("male") AS "male",
#     SUM("female") AS "female"
# FROM "census"
# GROUP BY "district"
# ORDER BY "population" DESC;
# Out:
#  * sqlite:///./census/census.db?check_same_thread=false
# []

# %%
# %sql SELECT * FROM "most_populated";
# Out:
#  * sqlite:///./census/census.db?check_same_thread=false
# [('Kathmandu', 537916, 275806, 1988606, 1001798, 986808),
#  ('Morang', 274651, 241415, 1147186, 557527, 589659),
#  ('Rupandehi', 241432, 195087, 1117667, 546297, 571370),
#  ('Jhapa', 246138, 219989, 994090, 477496, 516594),
#  ('Sunsari', 216874, 181777, 932452, 452087, 480365),
#  ('Kailali', 200513, 183692, 907816, 436652, 471164),
#  ('Dhanusa', 180826, 146470, 872713, 433812, 438901),
#  ('Sarlahi', 168406, 138412, 856443, 432599, 423844),
#  ('Rautahat', 139355, 111563, 821205, 412269, 408936),
#  ('Siraha', 154593, 123536, 748416, 369049, 379367),
#  ('Bara', 134362, 112301, 742667, 379072, 363595),
#  ('Mahottari', 145900, 117494, 715040, 354952, 360088),
#  ('Chitawan', 182041, 153629, 713750, 347173, 366577),
#  ('Saptari', 151291, 124324, 711759, 354183, 357576),
#  ('Kapilbastu', 122689, 103739, 684602, 335573, 349029),
#  ('Dang', 165742, 149249, 673072, 318994, 354078),
# ...
