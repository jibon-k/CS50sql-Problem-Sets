# %%
db = "./snap/snap.db"

# %%
# %load_ext sql
# %config SqlMagic.feedback=False
# %sql sqlite:///{db}?check_same_thread=false
# %sql SELECT name FROM sqlite_master WHERE type='table';
# Out:
#  * sqlite:///./snap/snap.db?check_same_thread=false
# [('users',), ('friends',), ('messages',)]

# %%
# %sql SELECT * FROM sqlite_master;
# Out:
#  * sqlite:///./snap/snap.db?check_same_thread=false
# [('table', 'users', 'users', 2, 'CREATE TABLE "users" (\n    "id" INTEGER,\n    "username" TEXT NOT NULL UNIQUE,\n    "phone_number" TEXT NOT NULL UNIQUE,\n    "joined_date" NUMERIC NOT NULL,\n    "last_login_date" NUMERIC NOT NULL,\n    PRIMARY KEY("id")\n)'),
#  ('index', 'sqlite_autoindex_users_1', 'users', 3, None),
#  ('index', 'sqlite_autoindex_users_2', 'users', 4, None),
#  ('table', 'friends', 'friends', 5, 'CREATE TABLE "friends" (\n    "user_id" INTEGER,\n    "friend_id" INTEGER,\n    "friendship_date" NUMERIC NOT NULL,\n    PRIMARY KEY("user_id", "friend_id"),\n    FOREIGN KEY("user_id") REFERENCES "users"("id"),\n    FOREIGN KEY("friend_id") REFERENCES "users"("id")\n)'),
#  ('index', 'sqlite_autoindex_friends_1', 'friends', 6, None),
#  ('table', 'messages', 'messages', 7, 'CREATE TABLE "messages" (\n    "id" INTEGER,\n    "from_user_id" INTEGER,\n    "to_user_id" INTEGER,\n    "picture" TEXT NOT NULL,\n    "sent_timesta ... (107 characters truncated) ... T NULL,\n    PRIMARY KEY("id"),\n    FOREIGN KEY("from_user_id") REFERENCES "users"("id"),\n    FOREIGN KEY("to_user_id") REFERENCES "users"("id")\n)'),
#  ('index', 'search_users_by_last_login', 'users', 8, 'CREATE INDEX "search_users_by_last_login"\nON "users"("last_login_date")'),
#  ('index', 'search_messages_by_from_user_id', 'messages', 9, 'CREATE INDEX "search_messages_by_from_user_id"\nON "messages"("from_user_id")'),
#  ('index', 'search_messages_by_to_user_id', 'messages', 10, 'CREATE INDEX "search_messages_by_to_user_id"\nON "messages"("to_user_id")')]

# %%
# %sql SELECT * FROM "users" LIMIT 10;
# Out:
#  * sqlite:///./snap/snap.db?check_same_thread=false
# [(1, 'exceptionaltreasure472', '668792803859', '2007-08-05', '2023-08-02'),
#  (2, 'tranquillove678', '039021893264', '2009-07-01', '2023-06-24'),
#  (3, 'vibrantcompassion491', '586016865872', '2016-01-31', '2024-05-01'),
#  (4, 'cheerfulbonus23', '089738617171', '2018-04-29', '2024-01-05'),
#  (5, 'lovelylove87', '372843653836', '2020-12-25', '2024-04-14'),
#  (6, 'admirablesuccess919', '311360780277', '2011-12-05', '2023-02-14'),
#  (7, 'sensationaltreasure750', '981182716695', '2006-01-06', '2023-01-30'),
#  (8, 'joyfulclarity763', '755759054177', '2008-07-20', '2024-02-22'),
#  (9, 'youthfulrespect382', '469554055661', '2011-12-24', '2023-08-11'),
#  (10, 'awesomebravery536', '751773032513', '2022-06-24', '2024-07-08')]

# %%
# %%sql
# EXPLAIN QUERY PLAN
# SELECT * FROM "users"
# WHERE "last_login_date" >= '2024-01-01';
# Out:
#  * sqlite:///./snap/snap.db?check_same_thread=false
# [(3, 0, 203, 'SEARCH users USING INDEX search_users_by_last_login (last_login_date>?)')]

# %%
# %%sql
# SELECT count(*) FROM "users"
# WHERE "last_login_date" >= '2024-01-01';
# Out:
#  * sqlite:///./snap/snap.db?check_same_thread=false
# [(1182,)]

# %%
# %sql SELECT * FROM "messages" LIMIT 10;
# Out:
#  * sqlite:///./snap/snap.db?check_same_thread=false
# [(1, 214, 1258, 'BkDquPHN.jpg', '2020-09-19 14:00:06', '2020-09-20 12:26:45', '2020-09-20 12:27:15'),
#  (2, 1023, 1017, 'llunYIAS.jpg', '2022-12-27 07:30:38', '2022-12-27 13:56:23', '2022-12-27 13:56:53'),
#  (3, 1821, 1174, 'bOSNALSN.jpg', '2023-01-18 04:13:37', '2023-01-18 21:12:00', '2023-01-18 21:12:30'),
#  (4, 1528, 73, 'DVoJZlar.jpg', '2021-03-03 13:12:07', '2021-03-04 00:42:08', '2021-03-04 00:42:38'),
#  (5, 259, 1133, 'UjReSJmX.jpg', '2023-07-20 18:30:13', '2023-07-21 16:36:18', '2023-07-21 16:36:48'),
#  (6, 2243, 1377, 'IgqjMPiV.jpg', '2023-03-10 13:32:12', '2023-03-10 23:40:54', '2023-03-10 23:41:24'),
#  (7, 2275, 1446, 'KPvxDTOT.jpg', '2021-12-15 04:15:53', '2021-12-15 11:29:34', '2021-12-15 11:30:04'),
#  (8, 1075, 1870, 'EEExAKxV.jpg', '2023-04-01 02:37:29', '2023-04-02 00:07:53', '2023-04-02 00:08:23'),
#  (9, 483, 1406, 'JgFgGfIg.jpg', '2022-09-28 02:34:13', '2022-09-28 14:43:00', '2022-09-28 14:43:30'),
#  (10, 2268, 54, 'ueaKVphJ.jpg', '2021-09-12 20:14:42', '2021-09-13 19:24:55', '2021-09-13 19:25:25')]

# %%
# %%sql
# EXPLAIN QUERY PLAN
# SELECT "expires_timestamp" FROM "messages"
# WHERE "id" = 151;
# Out:
#  * sqlite:///./snap/snap.db?check_same_thread=false
# [(2, 0, 33, 'SEARCH messages USING INTEGER PRIMARY KEY (rowid=?)')]

# %%
# %%sql
# SELECT "expires_timestamp" FROM "messages"
# WHERE "id" = 151;
# Out:
#  * sqlite:///./snap/snap.db?check_same_thread=false
# [('2021-10-04 13:20:12',)]

# %%
# %%sql
# EXPLAIN QUERY PLAN
# SELECT "to_user_id"
# FROM "messages"
# WHERE "from_user_id" = (
#     SELECT "id" FROM "users"
#     WHERE "username" = 'creativewisdom377'
# )
# GROUP BY "to_user_id"
# ORDER BY count(*) DESC
# LIMIT 3;
# Out:
#  * sqlite:///./snap/snap.db?check_same_thread=false
# [(9, 0, 61, 'SEARCH messages USING INDEX search_messages_by_from_user_id (from_user_id=?)'),
#  (12, 0, 0, 'SCALAR SUBQUERY 1'),
#  (16, 12, 39, 'SEARCH users USING COVERING INDEX sqlite_autoindex_users_1 (username=?)'),
#  (28, 0, 0, 'USE TEMP B-TREE FOR GROUP BY'),
#  (68, 0, 0, 'USE TEMP B-TREE FOR ORDER BY')]

# %%
# %%sql
# SELECT "to_user_id"
# FROM "messages"
# WHERE "from_user_id" = (
#     SELECT "id" FROM "users"
#     WHERE "username" = 'creativewisdom377'
# )
# GROUP BY "to_user_id"
# ORDER BY count(*) DESC
# LIMIT 3;
# Out:
#  * sqlite:///./snap/snap.db?check_same_thread=false
# [(744,), (4,), (1104,)]

# %%
# %%sql
# EXPLAIN QUERY PLAN
# SELECT "from_user_id" FROM "messages"
# GROUP BY "to_user_id"
# ORDER BY count(*) DESC
# LIMIT 1;
# Out:
#  * sqlite:///./snap/snap.db?check_same_thread=false
# [(9, 0, 223, 'SCAN messages USING INDEX search_messages_by_to_user_id'),
#  (44, 0, 0, 'USE TEMP B-TREE FOR ORDER BY')]

# %%
# %%sql
# SELECT "from_user_id" FROM "messages"
# GROUP BY "to_user_id"
# ORDER BY count(*) DESC
# LIMIT 1;
# Out:
#  * sqlite:///./snap/snap.db?check_same_thread=false
# [(1988,)]

# %%
# %%sql
# EXPLAIN QUERY PLAN
# SELECT "friend_id"
# FROM "friends"
# WHERE "user_id" = (
#     SELECT "id" FROM "users"
#     WHERE "username" = 'lovelytrust487'
# )
# AND
# "friend_id" IN (
#     SELECT "friend_id"
#     FROM "friends"
#     WHERE "user_id" = (
#         SELECT "id" FROM "users"
#         WHERE "username" = 'exceptionalinspiration482'
#     )
# );
# Out:
#  * sqlite:///./snap/snap.db?check_same_thread=false
# [(2, 0, 55, 'SEARCH friends USING COVERING INDEX sqlite_autoindex_friends_1 (user_id=? AND friend_id=?)'),
#  (5, 0, 0, 'SCALAR SUBQUERY 1'),
#  (9, 5, 39, 'SEARCH users USING COVERING INDEX sqlite_autoindex_users_1 (username=?)'),
#  (21, 0, 0, 'LIST SUBQUERY 3'),
#  (24, 21, 55, 'SEARCH friends USING COVERING INDEX sqlite_autoindex_friends_1 (user_id=?)'),
#  (27, 21, 0, 'SCALAR SUBQUERY 2'),
#  (31, 27, 39, 'SEARCH users USING COVERING INDEX sqlite_autoindex_users_1 (username=?)'),
#  (46, 21, 0, 'CREATE BLOOM FILTER')]

# %%
# %%sql
# SELECT "friend_id"
# FROM "friends"
# WHERE "user_id" = (
#     SELECT "id" FROM "users"
#     WHERE "username" = 'lovelytrust487'
# )
# AND
# "friend_id" IN (
#     SELECT "friend_id"
#     FROM "friends"
#     WHERE "user_id" = (
#         SELECT "id" FROM "users"
#         WHERE "username" = 'exceptionalinspiration482'
#     )
# );
# Out:
#  * sqlite:///./snap/snap.db?check_same_thread=false
# [(1603,), (2142,), (2438,)]
